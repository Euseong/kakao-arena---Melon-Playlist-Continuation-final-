# %%
import json
import os
import re
import warnings
import random

import numpy as np
import scipy as sp
import pandas as pd

from numba import jit
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

# %%
pd.options.mode.chained_assignment = None

# %%
song_meta = pd.read_json('song_meta.json', typ = 'frame', encoding='utf-8')
train = pd.read_json('train.json', typ = 'frame', encoding='utf-8')

# %%
song_meta.head()
# Out:
#    album_id                                         album_name  \
# 0   2255639                       불후의 명곡 - 7080 추억의 얄개시대 팝송베스트
# 1    376431                      Bach : Partitas Nos. 2, 3 & 4
# 2   4698747                                                Hit
# 3   2644882  Feeling Right (Everything Is Nice) (Feat. Popc...
# 4   2008470                                            그남자 그여자
#
#   artist_id_basket artist_name_basket  id  issue_date song_gn_dtl_gnr_basket  \
# 0           [2727]  [Various Artists]   0    20140512               [GN0901]
# 1          [29966]   [Murray Perahia]   1    20080421       [GN1601, GN1606]
# 2           [3361]    [Peter Gabriel]   2    20180518               [GN0901]
# 3         [838543]           [Matoma]   3    20151016       [GN1102, GN1101]
# 4         [560160]         [Jude Law]   4    20110824       [GN1802, GN1801]
#
#   song_gn_gnr_basket                                          song_name
# 0           [GN0900]                                           Feelings
# 1           [GN1600]  Bach : Partita No. 4 In D Major, BWV 828 - II....
# 2           [GN0900]                    Solsbury Hill (Remastered 2002)
# 3           [GN1100]  Feeling Right (Everything Is Nice) (Feat. Popc...
# 4           [GN1800]                                            그남자 그여자

# %%
train.head()
# Out:
#                                                 tags      id  \
# 0                                                [락]   61281
# 1                                           [추억, 회상]   10532
# 2                                          [까페, 잔잔한]   76951
# 3  [연말, 눈오는날, 캐럴, 분위기, 따듯한, 크리스마스캐럴, 겨울노래, 크리스마스,...  147456
# 4                                               [댄스]   27616
#
#             plylst_title                                              songs  \
# 0                여행같은 음악  [525514, 129701, 383374, 562083, 297861, 13954...
# 1                요즘 너 말야  [432406, 675945, 497066, 120377, 389529, 24427...
# 2  편하게, 잔잔하게 들을 수 있는 곡.-  [83116, 276692, 166267, 186301, 354465, 256598...
# 3  크리스마스 분위기에 흠뻑 취하고 싶을때  [394031, 195524, 540149, 287984, 440773, 10033...
# 4               추억의 노래 ㅋ  [159327, 553610, 5130, 645103, 294435, 100657,...
#
#    like_cnt                updt_date
# 0        71  2013-12-19 18:36:19.000
# 1         1  2014-12-02 16:19:42.000
# 2        17  2017-08-28 07:09:34.000
# 3        33  2019-12-05 15:15:18.000
# 4         9  2011-10-25 13:54:56.000

# %% [markdown]
# ## train data 내 playlist에서 song  일부(20%)를 제거하는 train set 생성

# %%
# @jit(nopython=True)
def train_labelled(songs_list, tags_list, X_rate):
    # result[:,0]=songs_X
    # result[:,1]=songs_y
    # result[:,2]=tags_X
    # result[:,3]=tags_y
    i = 0
    songs_X, songs_y, tags_X, tags_y = [], [], [], []
    for songs, tags in zip(songs_list, tags_list):        
        if i > 9999 and i % 10000 == 0:
            print(i, "th completed", sep="")
        n_songs = len(songs)
        n_tags = len(tags)
        
        if n_songs + n_tags == 0:
            continue
        
        n_songs_Xi = round(X_rate*n_songs)
        n_tags_Xi = round(X_rate*n_tags)
        songs_index = random.shuffle(list(range(n_songs)))
        tags_index = random.shuffle(list(range(n_tags)))
        songs_Xi = songs[:n_songs_Xi]
        songs_yi = songs[n_songs_Xi:]
        tags_Xi = tags[:n_tags_Xi]
        tags_yi = tags[n_tags_Xi:]
        
        if not len(songs_X):
            songs_X, songs_y, tags_X, tags_y = [songs_Xi], [songs_yi], [tags_Xi], [tags_yi]
        else:
            songs_X += [songs_Xi]
            songs_y += [songs_yi]
            tags_X += [tags_Xi]
            tags_y += [tags_yi]
        
        i += 1
    return songs_X, songs_y, tags_X, tags_y

# %%
random.seed(1000)
new_train = train_labelled(list(train.songs), list(train.tags), 0.8)
# Out:
# 10000th completed
# 20000th completed
# 30000th completed
# 40000th completed
# 50000th completed
# 60000th completed
# 70000th completed
# 80000th completed
# 90000th completed
# 100000th completed
# 110000th completed

# %%
print(new_train[3])
# Out:
# [[], [], [], ['겨울왕국', '크리스마스송'], [], ['트렌드', '일렉'], ['이별'], ['회상'], ['인디'], ['락']]

# %%
train["songs_X"] = pd.Series(new_train[0])
train["songs_y"] = pd.Series(new_train[1])
train["tags_X"] = pd.Series(new_train[2])
train["tags_y"] = pd.Series(new_train[3])

# %%
train.head()
# Out:
#                                                 tags      id  \
# 0                                                [락]   61281
# 1                                           [추억, 회상]   10532
# 2                                          [까페, 잔잔한]   76951
# 3  [연말, 눈오는날, 캐럴, 분위기, 따듯한, 크리스마스캐럴, 겨울노래, 크리스마스,...  147456
# 4                                               [댄스]   27616
#
#             plylst_title                                              songs  \
# 0                여행같은 음악  [525514, 129701, 383374, 562083, 297861, 13954...
# 1                요즘 너 말야  [432406, 675945, 497066, 120377, 389529, 24427...
# 2  편하게, 잔잔하게 들을 수 있는 곡.-  [83116, 276692, 166267, 186301, 354465, 256598...
# 3  크리스마스 분위기에 흠뻑 취하고 싶을때  [394031, 195524, 540149, 287984, 440773, 10033...
# 4               추억의 노래 ㅋ  [159327, 553610, 5130, 645103, 294435, 100657,...
#
#    like_cnt                updt_date  \
# 0        71  2013-12-19 18:36:19.000
# 1         1  2014-12-02 16:19:42.000
# 2        17  2017-08-28 07:09:34.000
# 3        33  2019-12-05 15:15:18.000
# 4         9  2011-10-25 13:54:56.000
#
#                                              songs_X  \
# 0  [525514, 129701, 383374, 562083, 297861, 13954...
# 1  [432406, 675945, 497066, 120377, 389529, 24427...
# 2  [83116, 276692, 166267, 186301, 354465, 256598...
# 3  [394031, 195524, 540149, 287984, 440773, 10033...
# 4  [159327, 553610, 5130, 645103, 294435, 100657,...
#
#                                              songs_y  \
# 0                     [72552, 223955, 324992, 50104]
# 1  [181101, 472144, 414721, 75801, 315216, 192882...
# 2    [35784, 153029, 336743, 203558, 348801, 454550]
# 3  [457519, 453762, 349398, 631142, 406082, 54838...
# 4  [583375, 181670, 314344, 617473, 33244, 635753...
#
#                                            tags_X          tags_y
# 0                                             [락]              []
# 1                                        [추억, 회상]              []
# 2                                       [까페, 잔잔한]              []
# 3  [연말, 눈오는날, 캐럴, 분위기, 따듯한, 크리스마스캐럴, 겨울노래, 크리스마스]  [겨울왕국, 크리스마스송]
# 4                                            [댄스]              []

# %%
train.to_json("train_labelled.json", orient='records', force_ascii=False)

# %% [markdown]
# ## 노래들 간 co-occurrence를 이용하여 누락된 노래 100개 예측

# %%
# co-occurrence matrix for songs
num_songs = song_meta.shape[0]
def cooccur(song_lists):
    import scipy as sp
    i = 0
    result = sp.sparse.dok_matrix((num_songs,num_songs), dtype='int32')
    for songs in song_lists:
        if i > 9999 and i % 10000 == 0:
            print(i, "th completed", sep="")
        i = 0
        for song in songs:
            for co_occured_song in songs[(i+1):]:
                result[song, co_occured_song] += 1
                result[co_occured_song, song] += 1
            i += 1
    return result

# %%
# train.songs 이용 2시간 걸림
song_co_occurrence = cooccur(train.songs)

# %%
# song_co_occurrence_coo = song_co_occurrence.tocoo()
# sp.sparse.save_npz("train_song_co_occurrence.npz", song_co_occurrence_coo)

# %%
# train.songs_X 이용 
song_co_occurrence_reduced = cooccur(train.songs_X)

# %%
song_co_occurrence_reduced_coo = song_co_occurrence_reduced.tocoo()
sp.sparse.save_npz("train_song_co_occurrence_reduced.npz", song_co_occurrence_reduced_coo)

# %%
song_co_occurrence_csr = sp.sparse.load_npz("train_song_co_occurrence.npz").tocsr()

# %%
song_co_occurrence_csr
# Out:
# <707989x707989 sparse matrix of type '<class 'numpy.intc'>'
# 	with 278497102 stored elements in Compressed Sparse Row format>

# %% [markdown]
# - 특정 song이 포함될 conditional probability를 계산하기 위한 song 별 총 등장횟수 계산

# %%
train_song_count = {song:0 for song in range(len(song_meta))}

# %%
for songs in train.songs:
    for song in songs:
        train_song_count[song] += 1

# %%
train_song_count = np.array([train_song_count[i] for i in range(len(song_meta))])

# %%
print(train_song_count)
# Out:
# [ 2  0  0 ... 11  1  1]

# %% [markdown]
# ## 노래들과 태그의 co-occurrence를 이용하여 태그 10개 예측

# %%
# 태그 unique 값 추출
tags_dict = {tag:i for i, tag in enumerate(train.tags.explode().unique())}
index_tags = {index:tag for tag, index in tags_dict.items()}

# %%
# co-occurrence matrix for tags with respect to songs
def cooccur_tag(song_lists, tag_lists, n_songs, n_tags):
    import scipy as sp
    result = sp.sparse.dok_matrix((n_songs, n_tags), dtype='int16')
    i = 0
    for songs, tags in zip(song_lists, tag_lists):
        if i > 9999 and not i % 10000:
            print(i, "th list completed", sep="")
        songs_in_list = len(songs)
        for song in songs:
            for tag in tags:
                result[song, tags_dict[tag]] += 1
        i += 1
    return result

# %%
train.head()
# Out:
#                                                 tags      id  \
# 0                                                [락]   61281
# 1                                           [추억, 회상]   10532
# 2                                          [까페, 잔잔한]   76951
# 3  [연말, 눈오는날, 캐럴, 분위기, 따듯한, 크리스마스캐럴, 겨울노래, 크리스마스,...  147456
# 4                                               [댄스]   27616
#
#             plylst_title                                              songs  \
# 0                여행같은 음악  [525514, 129701, 383374, 562083, 297861, 13954...
# 1                요즘 너 말야  [432406, 675945, 497066, 120377, 389529, 24427...
# 2  편하게, 잔잔하게 들을 수 있는 곡.-  [83116, 276692, 166267, 186301, 354465, 256598...
# 3  크리스마스 분위기에 흠뻑 취하고 싶을때  [394031, 195524, 540149, 287984, 440773, 10033...
# 4               추억의 노래 ㅋ  [159327, 553610, 5130, 645103, 294435, 100657,...
#
#    like_cnt                updt_date
# 0        71  2013-12-19 18:36:19.000
# 1         1  2014-12-02 16:19:42.000
# 2        17  2017-08-28 07:09:34.000
# 3        33  2019-12-05 15:15:18.000
# 4         9  2011-10-25 13:54:56.000

# %%
tag_co_occurrence = cooccur_tag(train.songs, train.tags, n_songs=num_songs, n_tags=len(tags_dict))
tag_co_occurrence_coo = tag_co_occurrence.tocoo()
# sp.sparse.save_npz('train_tag_co_occurrence_coo.npz', tag_co_occurrence_coo)
# Out:
# 10000th list completed
# 20000th list completed
# 30000th list completed
# 40000th list completed
# 50000th list completed
# 60000th list completed
# 70000th list completed
# 80000th list completed
# 90000th list completed
# 100000th list completed
# 110000th list completed

# %%
tag_co_occurrence_coo = sp.sparse.load_npz("train_tag_co_occurrence_coo.npz")
tag_co_occurrence_csr = tag_co_occurrence_coo.tocsr()

# %% [markdown]
# - 특정 tag가 포함될 conditional probability를 계산하기 위한 tag 별 총 등장횟수 계산

# %%
train_tag_index_count = tag_co_occurrence_csr.sum(axis=0)

# %%
train_tag_index_count = {index:0 for index in range(len(tags_dict))}
train_tag_index_count = np.array([train_tag_index_count[i] for i in range(len(tags_dict))])

# %%
for tags in train.tags:
    for tag in tags:
        train_tag_index_count[tags_dict[tag]] += 1

# %%
train_tag_index_count
# Out:
# array([4007, 6520, 4579, ...,    1,    1,    1])

# %%
tag_co_occurrence_csr.sum(axis=0)
# Out:
# matrix([[124181, 370200, 256209, ...,     23,     29,      6]],
#        dtype=int32)

# %% [markdown]
# ## association analysis

# %%
# song 별로 support, confidence, lift 계산
nonzero_index = song_co_occurrence_csr.nonzero()

# %%
nonzero_index
# Out:
# (array([     0,      0,      0, ..., 707988, 707988, 707988], dtype=int32),
#  array([  1373,   7993,  13615, ..., 670071, 673281, 677431], dtype=int32))

# %%
print(nonzero_index[0].shape, nonzero_index[1].shape)
# Out:
# (278497102,) (278497102,)

# %% [markdown]
# # validation 데이터 예측

# %%
val = pd.read_json('val.json', typ = 'frame', encoding='utf-8')

# %%
print(val.shape)
val.head()
# Out:
# (23015, 6)
#   tags      id plylst_title  \
# 0   []  118598
# 1   []  131447       앨리스테이블
# 2   []   51464
# 3   []   45144
# 4   []   79929
#
#                                                songs  like_cnt  \
# 0  [373313, 151080, 275346, 696876, 165237, 52593...      1675
# 1                                                 []         1
# 2  [529437, 516103, 360067, 705713, 226062, 37089...        62
# 3  [589668, 21711, 570151, 320043, 13930, 599327,...        20
# 4  [672718, 121924, 102694, 683657, 201558, 38511...        20
#
#                  updt_date
# 0  2019-05-27 14:14:33.000
# 1  2014-07-16 15:24:24.000
# 2  2008-06-21 23:26:22.000
# 3  2017-10-30 18:15:43.000
# 4  2017-02-07 11:40:42.000

# %%
sum([1 if n_songs==0 else 0 for n_songs in list(map(lambda x: len(x), val.songs))])
# Out:
# 4379

# %% [markdown]
# #### validation 데이터에서  songs가 비어 있는 playlist는 4379개 (전체 playlist는 23015개)

# %% [markdown]
# ### validation song 예측

# %%
print("다른 song과 함께 포함된 횟수 :", np.array(song_co_occurrence_csr.sum(axis=1))[:10,0])
print("song 별 총 등장 횟수", list(map(lambda x : train_song_count[x], range(10)) ))
# Out:
# 다른 song과 함께 포함된 횟수 : [111   0   0 824 241 311  27  25   0 228]
# song 별 총 등장 횟수 [2, 0, 0, 8, 2, 5, 1, 1, 0, 2]

# %%
# 비어 있는 playlist에 대해서는 등장횟수 상위 100song으로 예측
train_songs_co_occurrence_rank = np.array(song_co_occurrence_csr.sum(axis=1))[:,0].argsort()[::-1]
train_songs_co_occurrence_rank
np.array(song_co_occurrence_csr.sum(axis=1))[train_songs_co_occurrence_rank]
# Out:
# array([[168958],
#        [153941],
#        [148093],
#        ...,
#        [     0],
#        [     0],
#        [     0]])

# %%
np.array(song_co_occurrence_csr[:10000, :].max(axis=0).todense())[0,:]
# Out:
# array([1, 0, 0, ..., 1, 1, 0], dtype=int32)

# %%
warnings.filterwarnings(action='ignore')
song_val_pred = []
for i, songs in enumerate(val.songs):
    if i > 0 and i % 1000 == 0:
        print(i, "th completed", sep="")
    
    if not songs:
        song_val_pred += [train_songs_co_occurrence_rank[:100].tolist()]
        continue
    
    song_i_pred = []
    song_i_candidate = np.array(song_co_occurrence_csr[songs,:].sum(axis=0))[0,:]
    song_i_candidate = song_i_candidate / train_song_count
    song_i_candidate[np.isnan(song_i_candidate)] = 0
    song_i_candidate = song_i_candidate.argsort()[::-1]
    
    count = 0
    for song in song_i_candidate:
        if not song in songs:
            song_i_pred += [song]
            count += 1
            if count == 100: break
    if count < 100:
        for song in train_songs_co_occurrence_rank:
            if not song in songs:
                song_i_pred += [song]
                count += 1
                if count == 100: break
    song_val_pred += [song_i_pred]
warnings.filterwarnings(action='default')
# Out:
# 1000th completed
# 2000th completed
# 3000th completed
# 4000th completed
# 5000th completed
# 6000th completed
# 7000th completed
# 8000th completed
# 9000th completed
# 10000th completed
# 11000th completed
# 12000th completed
# 13000th completed
# 14000th completed
# 15000th completed
# 16000th completed
# 17000th completed
# 18000th completed
# 19000th completed
# 20000th completed
# 21000th completed
# 22000th completed
# 23000th completed

# %%
print(train_songs_co_occurrence_rank[:100].tolist())
# Out:
# [116573, 144663, 366786, 357367, 675115, 654757, 133143, 549178, 610933, 13281, 339802, 11657, 701557, 650494, 625875, 449244, 627363, 169984, 461341, 26083, 643628, 339124, 174749, 348200, 300087, 505036, 88503, 132994, 37748, 663256, 645489, 117595, 407828, 295250, 302646, 581799, 253755, 463173, 493762, 672550, 173943, 473514, 140867, 377243, 520093, 446812, 27469, 209135, 543820, 663905, 648628, 152422, 13198, 497066, 680366, 531820, 427724, 224921, 146989, 350309, 6546, 580074, 42155, 464051, 237407, 232874, 215411, 349492, 75842, 246531, 523521, 333595, 485155, 118827, 424813, 246984, 67655, 396828, 187047, 351342, 152475, 629738, 443914, 590012, 579592, 459256, 413422, 418935, 628232, 236393, 586653, 601037, 422915, 235773, 668128, 422077, 210647, 547967, 95323, 374617]

# %%
print(song_val_pred[-3])
# Out:
# [284643, 473930, 274756, 264383, 542902, 584523, 606705, 93430, 562095, 349649, 397971, 555034, 276528, 541703, 646789, 630396, 358437, 327325, 222053, 518412, 494972, 575616, 354337, 565854, 449662, 38204, 702005, 65429, 590022, 159126, 316272, 604146, 94003, 53924, 252691, 220203, 91770, 283859, 70986, 452728, 216691, 200903, 310390, 313579, 365400, 339971, 338828, 557293, 51181, 420030, 314021, 11073, 133525, 677838, 84700, 224152, 262999, 522802, 621221, 335192, 545403, 65734, 481821, 130261, 697375, 405510, 161493, 188795, 565840, 210294, 123757, 631758, 693457, 229837, 116631, 632876, 479294, 427760, 540231, 288157, 269847, 29129, 388329, 617048, 650134, 396719, 586058, 13320, 607930, 88816, 655427, 590252, 376181, 320519, 309802, 669664, 114633, 647535, 535959, 224602]

# %% [markdown]
# ### validation tag 예측

# %%
tag_co_occurrence_csr
# Out:
# <707989x29160 sparse matrix of type '<class 'numpy.int16'>'
# 	with 10984669 stored elements in Compressed Sparse Row format>

# %%
train_tags_co_occurrence_rank = list(map(lambda x: index_tags[x], np.array(tag_co_occurrence_csr.sum(axis=0))[0,:].argsort()[::-1]))
print(train_tags_co_occurrence_rank[:10])
np.array(tag_co_occurrence_csr.sum(axis=0))[0,:][np.array(tag_co_occurrence_csr.sum(axis=0))[0,:].argsort()[::-1]]
# Out:
# ['기분전환', '감성', '드라이브', '발라드', '휴식', '잔잔한', '힐링', '사랑', '새벽', '추억']
# array([824433, 582545, 553464, ...,      1,      1,      1], dtype=int32)

# %%
print(index_tags)
# Out:
# {0: '락', 1: '추억', 2: '회상', 3: '까페', 4: '잔잔한', 5: '연말', 6: '눈오는날', 7: '캐럴', 8: '분위기', 9: '따듯한', 10: '크리스마스캐럴', 11: '겨울노래', 12: '크리스마스', 13: '겨울왕국', 14: '크리스마스송', 15: '댄스', 16: '운동', 17: '드라이브', 18: 'Pop', 19: '트로피컬하우스', 20: '힐링', 21: '기분전환', 22: '2017', 23: '팝', 24: '트렌드', 25: '일렉', 26: '짝사랑', 27: '취향저격', 28: '슬픔', 29: '고백', 30: '사랑', 31: '이별', 32: '일렉트로니카', 33: '포크', 34: '메탈', 35: '인디', 36: '록', 37: 'Metal', 38: '이일우', 39: 'M에센셜', 40: 'Rock', 41: 'kpop', 42: '걸그룹댄스', 43: '스트레스해소', 44: '새해', 45: '여행', 46: '프로필음악', 47: '카카오톡', 48: '소원', 49: '프로필', 50: '소망', 51: '다짐', 52: '카톡', 53: '듣고', 54: '우울', 55: '이거', 56: '힘내', 57: '힙합', 58: '느낌있는', 59: '밤', 60: '새벽', 61: 'RnB', 62: '감각적인', 63: '국내', 64: '그루브한', 65: '가을', 66: '재즈', 67: '감성', 68: '질리지않는', 69: '나만알고싶은', 70: '봄', 71: '설렘', 72: '비오는날', 73: '누군가생각날때', 74: '스밍', 75: '목록', 76: '폐막식', 77: '올림픽', 78: '엑소', 79: '조용히', 80: '혼자', 81: '또는', 82: '새벽감성', 83: '고민', 84: '맥주한잔', 85: '카페', 86: 'OST', 87: '어쿠스틱', 88: '편안한', 89: '에너지', 90: '듀엣', 91: '달달', 92: '피쳐링', 93: '남녀', 94: '신인', 95: '국힙', 96: '신나는', 97: '거슈윈', 98: '존윌리엄스', 99: '랩소디인블루', 100: '미국클래식', 101: '영화클래식', 102: '아메리칸클래식', 103: '겨울', 104: '아침', 105: '빅밴드', 106: '상쾌한', 107: '밝은', 108: '스윙', 109: '스윙재즈', 110: '휴식', 111: '여름', 112: '매장음악', 113: '헬스', 114: '스포츠', 115: '피트니스', 116: '다이어트', 117: '런닝', 118: '레깅스', 119: '필라테스', 120: '산책', 121: '요가', 122: '발라드', 123: '캐롤', 124: '위로', 125: '80년대', 126: '90년대발라드', 127: '올드송', 128: '90년대', 129: '옛날노래', 130: '월드', 131: '연주', 132: '클럽', 133: '스트레스', 134: '주말', 135: '오후', 136: '나른한', 137: 'Chillout', 138: '나만들을꺼', 139: '나만들을거얌', 140: '중국음악', 141: '광동', 142: '홍콩', 143: '대만', 144: '중국노래', 145: '중국', 146: '중음', 147: '내가좋아하는음악트랙', 148: '노래추천', 149: '인디추천', 150: '이달의인디포크', 151: '음악추천', 152: '추천노래', 153: '숨겨진', 154: '유럽여행', 155: '공기정화', 156: '피톤치드', 157: '연주곡', 158: '사무실', 159: '알앤비', 160: '불금', 161: 'ballads', 162: '차막힘', 163: '차막힐때', 164: '졸릴때', 165: '달달한', 166: '연애', 167: '썸', 168: '노래모음', 169: '히트곡', 170: '린아', 171: '선데이', 172: '스테파니', 173: '명곡', 174: '시간순', 175: '천상지희', 176: '다나', 177: '독서를돕는음악', 178: 'dance', 179: 'EDMFloor', 180: 'EDM', 181: 'electronica', 182: '빌로우', 183: '펍', 184: '매장', 185: '그루브', 186: '라운지', 187: '퇴근길', 188: '세련된', 189: '한강', 190: '드라이브할때신나는노래', 191: '자기전', 192: '랩', 193: '비트좋은', 194: '섹시', 195: '분위기좋은', 196: '뉴에이지', 197: '월드뮤직', 198: '조용한', 199: '무드', 200: '스웩', 201: '잔잔하게', 202: '조용하게', 203: '저스디스', 204: '힙합엘이', 205: '니엘', 206: '꿀', 207: '보이스', 208: '뺏고싶다', 209: '성대', 210: '버스', 211: '도입부', 212: '트렌디', 213: '런쥔', 214: '라디오', 215: '포근함', 216: '따스한', 217: '벚꽃', 218: 'Takealook', 219: '떄껄룩', 220: '플레이리스트', 221: '팝음악', 222: '팝송추천', 223: '유튜브', 224: '떼껄룩', 225: '카페음악', 226: 'Jazz', 227: '흐린날', 228: '힙한', 229: '1990', 230: '1990년대', 231: '자연주의', 232: 'MTV', 233: '언플러그드', 234: 'unplugged', 235: '프로그레시브하우스', 236: '빅룸', 237: '시원', 238: '바다', 239: '신나는노래', 240: '비', 241: '아련', 242: '멜로', 243: '치명', 244: '아드레날린', 245: '샤우팅', 246: '강렬한사운드', 247: '운동할때듣는', 248: 'rockisnotdead', 249: '여자아이돌', 250: '싱어송라이터', 251: '인디밴드', 252: '귀호강', 253: '미러볼뮤직', 254: '인디뮤직', 255: '잠', 256: '일상', 257: '추위', 258: '자장가', 259: '내적댄스폭발', 260: '페스티벌음악', 261: '몽환적인', 262: '일렉트로닉', 263: '힙합갬성', 264: '흥얼흥얼', 265: '쇼미', 266: '외힙', 267: '기리보이의노래는길이보인다', 268: '왜이리딱딱한것이냐', 269: '기분좋은', 270: '100번', 271: 'jazzymood', 272: '7살', 273: '9살', 274: '8살', 275: '키즈동화', 276: '8', 277: '쇼미더머니', 278: '가을밤', 279: '영국', 280: '기타', 281: '2016멜로디포레스트캠프', 282: '자연', 283: '음악', 284: '쉼표', 285: '추천', 286: '아무생각없이', 287: '아무노래', 288: '아무거나', 289: '생각', 290: '비_오는_날', 291: '비_오는날', 292: '숨은명곡', 293: '야경', 294: '노래', 295: '신나는곡', 296: '썸머', 297: '휴가', 298: '바캉스', 299: '해변', 300: '빌보드Hot50', 301: '빌보드', 302: '펑크락', 303: 'Maroon', 304: '위대함', 305: 'Coldplay', 306: '느껴져', 307: '날려버려', 308: 'Greenday', 309: '팝송', 310: '여자가수', 311: '명품발라드', 312: '고음병', 313: '연인', 314: 'mood', 315: '빗물같은', 316: '거짓말', 317: '아픈', 318: '찬송', 319: '오승훈', 320: 'GZ', 321: '파워워킹', 322: '흥겨운', 323: '출근길', 324: '맥주', 325: '비트', 326: 'CCM', 327: '소울', 328: '가요', 329: ...

# %%
warnings.filterwarnings(action='ignore')
tag_val_pred = []
tag_top10 = [train_tags_co_occurrence_rank[:10]]
for i, songs in enumerate(val.songs):
    if i > 0 and i % 1000 == 0:
        print(i, "th completed", sep="")
    
    if not songs:
        tag_val_pred += tag_top10
        continue
    
    tag_i_pred = []
    tag_i_candidate = np.array(tag_co_occurrence_csr[songs,:].sum(axis=0))[0,:]
    tag_i_candidate = tag_i_candidate / train_tag_index_count
    tag_i_candidate[np.isnan(tag_i_candidate)] = 0
    tag_i_candidate = tag_i_candidate.argsort()[::-1]
    
    tags = val.tags[i]
    count = 0
    for tag_index in tag_i_candidate:
        tag = index_tags[tag_index]
        if not tag in tags:
            tag_i_pred += [tag]
            count += 1
            if count == 10: break
    

    tag_val_pred += [tag_i_pred]
warnings.filterwarnings(action='default')
# Out:
# 1000th completed
# 2000th completed
# 3000th completed
# 4000th completed
# 5000th completed
# 6000th completed
# 7000th completed
# 8000th completed
# 9000th completed
# 10000th completed
# 11000th completed
# 12000th completed
# 13000th completed
# 14000th completed
# 15000th completed
# 16000th completed
# 17000th completed
# 18000th completed
# 19000th completed
# 20000th completed
# 21000th completed
# 22000th completed
# 23000th completed

# %%
tag_top10[0]
# Out:
# ['기분전환', '감성', '드라이브', '발라드', '휴식', '잔잔한', '힐링', '사랑', '새벽', '추억']

# %%
tag_val_pred[0]
# Out:
# ['가족영화',
#  '영원한감동',
#  '디즈니애니메이션ost',
#  '메리포핀스',
#  '스칼렛요한슨',
#  '연주노래',
#  '정글북',
#  '도리를찾아서',
#  '인크레더블',
#  '라푼젤']

# %%
val.head()
# Out:
#   tags      id plylst_title  \
# 0   []  118598
# 1   []  131447       앨리스테이블
# 2   []   51464
# 3   []   45144
# 4   []   79929
#
#                                                songs  like_cnt  \
# 0  [373313, 151080, 275346, 696876, 165237, 52593...      1675
# 1                                                 []         1
# 2  [529437, 516103, 360067, 705713, 226062, 37089...        62
# 3  [589668, 21711, 570151, 320043, 13930, 599327,...        20
# 4  [672718, 121924, 102694, 683657, 201558, 38511...        20
#
#                  updt_date
# 0  2019-05-27 14:14:33.000
# 1  2014-07-16 15:24:24.000
# 2  2008-06-21 23:26:22.000
# 3  2017-10-30 18:15:43.000
# 4  2017-02-07 11:40:42.000

# %%
song_meta.iloc[val.songs[0], :]
# Out:
#                                   song_gn_dtl_gnr_basket  issue_date  \
# 373313                  [GN2207, GN1501, GN1506, GN1509]    20150101
# 151080                  [GN2207, GN1509, GN1501, GN1506]    20150312
# 275346                                  [GN1301, GN1302]    20150814
# 696876                                  [GN1301, GN1302]    20151006
# 165237          [GN2207, GN1501, GN0901, GN1509, GN1506]    20151030
# 525935          [GN2207, GN0901, GN1509, GN1501, GN1506]    20160212
# 457812          [GN2207, GN0901, GN1509, GN1501, GN1506]    20171110
# 371709                  [GN2207, GN1509, GN1501, GN1506]    20171103
# 170292                  [GN1503, GN1501, GN0908, GN0901]    20190522
# 438915                          [GN1503, GN1501, GN1509]    20000513
# 162569                                  [GN1503, GN1501]    20081118
# 161136                                  [GN1503, GN1501]    20081118
# 310892                          [GN1501, GN1506, GN1509]    20110614
# 608704          [GN2207, GN0901, GN1509, GN1501, GN1506]    20110923
# 295701          [GN2207, GN1501, GN0901, GN1509, GN1506]    20120925
# 127698          [GN1501, GN1509, GN1506, GN0902, GN1001]    20121030
# 269427          [GN2207, GN1501, GN0901, GN1509, GN1506]    20131202
# 592526          [GN2207, GN1501, GN0901, GN1509, GN1506]    20131202
# 110696                                  [GN1503, GN1501]    20140626
# 368214  [GN1509, GN2207, GN1003, GN1001, GN1501, GN1506]    20141103
# 24386                                   [GN1503, GN1501]    20150309
# 104455                  [GN2207, GN1501, GN1506, GN1509]    20150101
# 61612           [GN2207, GN1501, GN0901, GN1509, GN1506]    19950101
# 151421          [GN2207, GN0901, GN1509, GN1501, GN1506]    19950101
# 416023                          [GN1501, GN1506, GN1509]    19960703
# 320447                  [GN2207, GN1509, GN1501, GN1506]    20181005
# 19606                   [GN2207, GN1501, GN1506, GN1509]    20021119
#
#                                                album_name  album_id  \
# 373313  Walt Disney Records The Legacy Collection: Pin...   2308104
# 151080           겨울왕국 열기 OST (Making Today A Perfect Day)   2308739
# 275346                                     Friend Like Me   2334904
# 696876  Ev&#39;rybody Wants To Be A Cat (From &#34;The...   2643514
# 165237                            We Love Disney (Deluxe)   2647713
# 525935                         영화 주토피아 OST (Zootopia OST)   2666420
# 457812          Coco (Original Motion Picture Soundtrack)  10105939
# 371709  Olaf&#39;s Frozen Adventure (Original Soundtrack)  10108314
# 170292       Aladdin (Original Motion Picture Soundtrack)  10288448
# 438915                                      쿠스코? 쿠스코! OST     41158
# 162569                                             볼트 OST    477452
# 161136                                             볼트 OST    477452
# 310892                                            카 2 OST   1317283
# 608704                              Best of The Lion King   2117568
# 295701                           Frankenweenie Unleashed!   2151188
# 127698                                         주먹왕 랄프 OST   2165582
# 269427                          겨울왕국 OST (Deluxe Edition)   2219433
# 592526                                           겨울왕국 OST   2225293
# 110696                                        Still I Fly    149542
# 368214    Big Hero 6 (Original Motion Picture Soundtrack)   2288829
# 24386     Cinderella (Original Motion Picture Soundtrack)   2307850
# 104455  Walt Disney Records The Legacy Collection: Pin...   2308104
# 61612                                            인어공주 OST     27363
# 151421                                           인어공주 OST     27363
# 416023                                        노틀담의 꼽추 OST     27548
# 320447        Tarzan (Original Motion Picture Soundtrack)     27827
# 19606                                             보물성 OST     29511
#
#                         artist_id_basket  \
# 373313                          [353277]
# 151080         [232538, 746208, 2758138]
# 275346                          [181769]
# 696876                          [871816]
# 165237                          [742133]
# 525935                           [10379]
# 457812                          [553325]
# 371709  [746208, 232538, 746216, 407770]
# 170292                           [27242]
# 438915                           [28192]
# 162569                          [254676]
# 161136                          [327767]
# 310892                          [105176]
# 608704                   [666718, 33674]
# 295701                           [35750]
# 127698                          [177834]
# 269427          [746208, 746210, 746211]
# 592526                          [232538]
# 110696                          [698241]
# 368214                          [169595]
# 24386                           [234970]
# 104455                   [29921, 560361]
# 61612                            [29233]
# 151421                           [51017]
# 416023                          [103514]
# 320447                            [3382]
# 19606                           [710763]
#
#                                                 song_name  \
# 373313                            I&#39;ve Got No Strings
# 151080                         Making Today A Perfect Day
# 275346            Friend Like Me (From &#34;Aladdin&#34;)
# 696876  Ev’rybody Wants To Be A Cat (From &#34;The Ari...
# 165237     Colors Of The Wind (From &#34;Pocahontas&#34;)
# 525935  Try Everything (From &#34;Zootopia&#34;/Soundt...
# 457812  Remember Me (D&#250;o) (From &#34;Coco&#34;/So...
# 371709  When We&#39;re Together (From &#34;Olaf&#39;s ...
# 170292  Arabian Nights (2019) (From &#34;Aladdin&#34;/...
# 438915                             My Funny Friend And Me
# 162569          I Thought I Lost You (With John Travolta)
# 161136                                Barking At The Moon
# 310892  You Might Think (From &#34;Cars 2&#34;/Soundtr...
# 608704  Circle of Life (From &#34;The Lion King&#34;/ ...
# 295701                                       Strange Love
# 127698                                  Shut Up And Drive
# 269427                    Do You Want To Build A Snowman?
# 592526                                          Let It Go
# 110696                                        Still I Fly
# 368214   Immortals (From &#34;Big Hero 6&#34;/Soundtrack)
# 24386   Bibbidi-Bobbidi-Boo (The Magic Song) (From &#3...
# 104455                          When You Wish Upon a Star
# 61612   Part of Your World (From &#34;The Little Merma...
# 151421  Under the Sea (From &#34;The Little Mermaid&#3...
# 416023                                            Someday
# 320447  You&#39;ll Be In My Heart (From &#34;Tarzan&#3...
# 19606                        I`m Still Here (Jim`s Theme)
#
#               song_gn_gnr_basket  \
# 373313          [GN1500, GN2200]
# 151080          [GN1500, GN2200]
# 275346                  [GN1300]
# 696876                  [GN1300]
# 165237  [GN1500, GN0900, GN2200]
# 525935  [GN1500, GN0900, GN2200]
# 457812  [GN1500, GN0900, GN2200]
# 371709          [GN1500, GN2200]
# 170292          [GN1500, GN0900]
# 438915                  [GN1500]
# 162569                  [GN1500]
# 161136                  [GN1500]
# 310892                  [GN1500]
# 608704  [GN1500, GN0900, GN2200]
# 295701  [GN1500, GN0900, GN2200]
# 127698  [GN1500, GN0900, GN1000]
# 269427  [GN1500, GN0900, GN2200]
# 592526  [GN1500, GN0900, GN2200]
# 110696                  [GN1500]
# 368214  [GN1500, GN2200, GN1000]
# 24386                   [GN1500]
# 104455          [GN1500, GN2200]
# 61612   [GN1500, GN0900, GN2200]
# 151421  [GN1500, GN0900, GN2200]
# 416023                  [GN1500]
# 320447          [GN1500, GN2200]
# 19606           [GN1500, GN2200]
#
#                                        artist_name_basket      id
# 373313                                     [Dickie Jones]  373313
# 151080  [Idina Menzel, Kristen Bell, Cast of Frozen Fe...  151080
# 275346                                            [Ne-Yo]  275346
# 696876                                    [Charles Perry]  696876
# 165237                                       [Tori Kelly]  165237
# 525935                                          [Shakira]  525935
# 457812                                           [Miguel]  457812
# 371709  [Kristen Bell, Idina Menzel, Josh Gad, Jonatha...  371709
# 170292                                       [Will Smith]  170292
# 438915                                            [Sting]  438915
# 162569                                      [Miley Cyrus]  162569
# 161136                                      [Jenny Lewis]  161136
# 310892                                           [Weezer]  310892
# 608704                           [Carmen Twillie, Lebo M]  608704
# 295701                                          [Karen O]  295701
# 127698                                          [Rihanna]  127698
# 269427       [Kristen Bell, Agatha Lee Monn, Katie Lopez]  269427
# 592526                                     [Idina Menzel]  592526
# 110696                                      [Spencer Lee]  110696
# 368214                                     [Fall Out Boy]  368214
# 24386                              [Helena Bonham Carter]   24386
# 104455              [Cliff Edwards, Disney Studio Chorus]  104455
# 61612                                       [Jodi Benson]   61612
# 151421                                 [Samuel E. Wright]  151421
# 416023                                        [All-4-One]  416023
# 320447                                     [Phil Collins]  320447
# 19606                                      [John Rzeznik]   19606

# %%
print(list(song_meta.song_name[song_val_pred[0]]))
# Out:
# ['The Incredibles (인크레더블) - Road Trip / Missile Lock / The Glory Days', 'Wall-E (월-E)', 'Into The Open Air (From &#34;Brave&#34;/Soundtrack)', 'No Way Out', '알라딘 (Aladdin) - Arabian Nights', 'The Nick of Time (From &#34;Zootopia&#34;/Score)', 'Woodland Symphony / Once Upon a Dream', 'Mickey Mouse Club Book Song', '헤라클레스 (Hercules) - Go The Distance', 'First Flight (From “Big Hero 6”/Score)', 'The Siamese Cat Song/What&#39;s Going on Down There', 'Perfect World', 'Real Gone (From &#34;Cars&#34;/Soundtrack Version)', 'The Time Of Your Life (From &#34;A Bug&#39;s Life&#34;/Score)', 'Collision of Worlds (From &#34;Cars 2&#34;/Soundtrack Version)', 'The Blue Fairy', 'If I Didn&#39;t Have You (From &#34;Monsters, Inc.&#34;/Soundtrack Version)', 'Toy Story (토이스토리) - You`ve Got A Friend In Me', 'Finding Nemo (니모를 찾아서) - Finding Nemo / Nemo Egg', 'My Own Home', 'We Can Still Stop Her (From &#34;Inside Out&#34;/Score)', 'Whistle While You Work', 'Pink Elephants on Parade (From &#34;Dumbo&#34; / Soundtrack Version)', 'La Llorona (De “Coco”/Versi&#243;n de la Banda Sonora)', 'My Strongest Suit (Original Version)', 'Foxy Fakeout (From &#34;Zootopia&#34;/Score)', 'Stay With Me (From “Into the Woods”/Soundtrack Version)', 'Down in New Orleans (Finale) (From &#34;The Princess and the Frog&#34;/Soundtrack Version)', 'Wreck-It, Wreck-It Ralph (From &#34;Wreck-It Ralph&#34;/Soundtrack Version)', 'Christopher Robin (From &#34;Christopher Robin&#34;/Soundtrack Version)', 'Know Who You Are', 'Les Poissons (From &#34;The Little Mermaid” / Soundtrack Version)', 'Ma Belle Evangeline (From &#34;The Princess and the Frog&#34;/Soundtrack Version) (Feat. Terence Blanchard)', 'Friend Like Me', 'Finding Nemo', 'Tala`s Deathbed', 'Rainbow Connection', 'Hercules (헤라클레스) - Go The Distance (Inst.)', 'The Star Shines (Edit From `The Bfg` Movie Trailer)', 'Wonderful (From &#34;Wicked&#34; Original Broadway Cast Recording/2003)', 'Nobody Knows', 'Arabian Nights', 'Heaven`s Light/Hellfire', 'A Guy Like You', 'More (Outtake)', 'Some Day My Prince Will Come', 'Prince Ali', 'Cruella De Vil', '길을 알아 (피날레) (From &#34;Moana&#34;/Soundtrack Version/Finale)', 'Topsy Turvy', 'An Innocent Warrior', 'How Far I`ll Go (Reprise)', 'Le Festin (From &#34;Ratatouille&#34;/Soundtrack Version)', 'No More I Love Yous', 'Kiss The Girl (From &#34;The Little Mermaid&#34;/Vocal)', 'You`re Welcome (Feat. Lin-Manuel Miranda) (Jordan Fisher / Lin-Manuel Miranda Ver.)', 'Hold On To Your Dream', 'Mine, Mine, Mine', 'I Just Can&#39;t Wait to Be King (From &#34;The Lion King&#34;/Soundtrack Version)', 'We Know The Way (Finale)', 'Hawaiian Roller Coaster Ride (Disneymania3 Album Ver.)', 'Fathoms Below (Remastered 2014)', 'I Can&#39;t Let You Throw Yourself Away (From &#34;Toy Story 4&#34;/Soundtrack Version)', 'The Tear Heals (From &#34;Tangled&#34;/Score)', 'Beautiful Life (From the Motion Picture Abominable)', 'Friends on the Other Side (From &#34;The Princess and the Frog&#34; / Soundtrack Version)', 'Ever Ever After', 'First Day of School (From &#34;Inside Out&#34;/Score)', 'The Second Star To The Right (피터팬)', 'Memory Lanes (From &#34;Inside Out&#34;/Score)', 'Main Title (Bella Notte)/The Wag of a Dog&#39;s Tail', 'Dig a Little Deeper (From &#34;The Princess and the Frog&#34;/Soundtrack Version) (Feat. The Pinnacle Gospel Choir)', 'Main Titles (Remastered 2014)', 'I Just Can&#39;t Wait to Be King (From &#34;The Lion King&#34;/Soundtrack Version)', 'The Library (From &#34;Beauty and the Beast&#34;/Score)', 'Carl Goes Up (From &#34;Up&#34;/Score)', 'Anpan Man No March (호빵맨 행진곡) (날아라!호빵맨 오프닝)', 'The Dress (From &#34;Beauty and the Beast&#34;/Score)', 'Following The Leader', 'Gaston (From &#34;Beauty and the Beast&#34; / Soundtrack Version)', 'Main Title (OST From `Dumbo`)', 'Prologue (From &#34;Tangled&#34;/Score)', 'Great Spirits', 'I Love My Shirt', 'Born to Shine', 'Main Title: Prologue (From &#34;Beauty and the Beast&#34;/Score)', 'Can You Feel the Love Tonight (From &#34;The Lion King&#34; ...

# %%
val_result = [{'id':val.id[i], 'songs':song_val_pred[i], 'tags':tag_val_pred[i]} for i in range(val.shape[0])]

# %%
len(val_result)
# Out:
# 23015

# %%
val_result = re.sub("\'", '\"', str(val_result))

# %%
with open('results.json', 'w', encoding='utf-8') as f:
    f.write(str(val_result))
